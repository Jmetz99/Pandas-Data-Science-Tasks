# %%
import pandas as pd
import os

# %% [markdown]
# #### Merging 12 months of Sales Data into a single file

# %%
data_files = os.listdir('Sales_Data/')
df = pd.DataFrame()
for file in data_files:
    data = pd.read_csv(f'Sales_Data/{file}')
    df = pd.concat([data, df], ignore_index=True)

# %%
df.to_csv('./Sales_Data/all_data.csv', index = False)

# %% [markdown]
# #### Read in updated Dataframe

# %%
all_data = pd.read_csv('./Sales_Data/all_data.csv')

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   209921        USB-C Charging Cable                1      11.95
# 1   209922          Macbook Pro Laptop                1     1700.0
# 2   209923             ThinkPad Laptop                1     999.99
# 3   209924            27in FHD Monitor                1     149.99
# 4   209925  Bose SoundSport Headphones                1      99.99
#
#        Order Date                       Purchase Address
# 0  06/23/19 19:34      950 Walnut St, Portland, ME 04101
# 1  06/30/19 10:05     80 4th St, San Francisco, CA 94016
# 2  06/24/19 20:18  402 Jackson St, Los Angeles, CA 90001
# 3  06/05/19 10:21         560 10th St, Seattle, WA 98101
# 4  06/25/19 18:58    545 2nd St, San Francisco, CA 94016

# %% [markdown]
# ### Clean up Data

# %% [markdown]
# #### Drop rows of NaN

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 339         NaN     NaN              NaN        NaN        NaN
# 630         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1136        NaN     NaN              NaN        NaN        NaN
# 1349        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 184678      NaN     NaN              NaN        NaN        NaN
# 184695      NaN     NaN              NaN        NaN        NaN
# 185042      NaN     NaN              NaN        NaN        NaN
# 185729      NaN     NaN              NaN        NaN        NaN
# 186463      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 339                 NaN
# 630                 NaN
# 735                 NaN
# 1136                NaN
# 1349                NaN
# ...                 ...
# 184678              NaN
# ...

# %%
all_data = all_data.dropna(how='all')

# %%
temp_df = all_data[all_data['Order Date'].str[0:2] == 'Or']
temp_df
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 158     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 990     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1679    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1684    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3126    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 184931  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185070  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185481  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185925  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185955  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address
# 158     Purchase Address
# 990     Purchase Address
# 1679    Purchase Address
# 1684    Purchase Address
# ...

# %%
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        209921        USB-C Charging Cable                1      11.95
# 1        209922          Macbook Pro Laptop                1     1700.0
# 2        209923             ThinkPad Laptop                1     999.99
# 3        209924            27in FHD Monitor                1     149.99
# 4        209925  Bose SoundSport Headphones                1      99.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %% [markdown]
# #### Best Month for Sales

# %%
# Add Month Column
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')

# %%
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        209921        USB-C Charging Cable                1      11.95
# 1        209922          Macbook Pro Laptop                1     1700.0
# 2        209923             ThinkPad Laptop                1     999.99
# 3        209924            27in FHD Monitor                1     149.99
# 4        209925  Bose SoundSport Headphones                1      99.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address  Month
# ...

# %%
all_data['Price Each'] = all_data['Price Each'].astype('float')
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].astype('int32')

# %% [markdown]
# ### Add a Sales Column

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        209921        USB-C Charging Cable                 1       11.95
# 1        209922          Macbook Pro Laptop                 1     1700.00
# 2        209923             ThinkPad Laptop                 1      999.99
# 3        209924            27in FHD Monitor                 1      149.99
# 4        209925  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186845   319666    Lightning Charging Cable                 1       14.95
# 186846   319667       AA Batteries (4-pack)                 2        3.84
# 186847   319668             Vareebadd Phone                 1      400.00
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                        Purchase Address  Month    Sales
# ...

# %%
all_data.groupby('Month').sum()
# Out:
# /var/folders/rj/nvyc7brx2p55bjzhqlxcrmpm0000gn/T/ipykernel_10528/2834125621.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_data.groupby('Month').sum()
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# ...

# %%
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
months = range(1,13)
results = all_data.groupby('Month').sum()
plt.bar(months, results["Sales"])
plt.xticks(months)
plt.ylabel('Sales in million USD($)')
plt.xlabel('Month')
# Out:
# /var/folders/rj/nvyc7brx2p55bjzhqlxcrmpm0000gn/T/ipykernel_10528/448220399.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results = all_data.groupby('Month').sum()
# Text(0.5, 0, 'Month')

# %% [markdown]
# ### What City had the Highest Number of Sales?

# %% [markdown]
# Beware of duplicates! There are two Portlands in the dataset so the below will aggregate the two together.

# %%
all_data['City'] = all_data['Purchase Address'].str.split(',').str[1]
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        209921        USB-C Charging Cable                 1       11.95
# 1        209922          Macbook Pro Laptop                 1     1700.00
# 2        209923             ThinkPad Laptop                 1      999.99
# 3        209924            27in FHD Monitor                 1      149.99
# 4        209925  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186845   319666    Lightning Charging Cable                 1       14.95
# 186846   319667       AA Batteries (4-pack)                 2        3.84
# 186847   319668             Vareebadd Phone                 1      400.00
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                        Purchase Address  Month  \
# ...

# %% [markdown]
# Instead we can use a lambda function or alter the above code slightly.

# %%
all_data['City'] = all_data['Purchase Address'].str.split(',').str[1:]
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        209921        USB-C Charging Cable                 1       11.95
# 1        209922          Macbook Pro Laptop                 1     1700.00
# 2        209923             ThinkPad Laptop                 1      999.99
# 3        209924            27in FHD Monitor                 1      149.99
# 4        209925  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186845   319666    Lightning Charging Cable                 1       14.95
# 186846   319667       AA Batteries (4-pack)                 2        3.84
# 186847   319668             Vareebadd Phone                 1      400.00
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                        Purchase Address  Month  \
# ...

# %% [markdown]
# To make the above slightly cleaner lets use lambda function:

# %%
def get_city(string):
    return string.split(',')[1]

def get_state(string):
    ste_zip = string.split(',')[2]
    return ste_zip.split(' ')[1]

# %%
all_data['City'] = all_data['Purchase Address'].apply(lambda x: f'{get_city(x)} ({get_state(x)})')
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        209921        USB-C Charging Cable                 1       11.95
# 1        209922          Macbook Pro Laptop                 1     1700.00
# 2        209923             ThinkPad Laptop                 1      999.99
# 3        209924            27in FHD Monitor                 1      149.99
# 4        209925  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186845   319666    Lightning Charging Cable                 1       14.95
# 186846   319667       AA Batteries (4-pack)                 2        3.84
# 186847   319668             Vareebadd Phone                 1      400.00
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                        Purchase Address  Month  \
# ...

# %% [markdown]
# Much better

# %%
all_data.groupby('City').sum()
# Out:
# /var/folders/rj/nvyc7brx2p55bjzhqlxcrmpm0000gn/T/ipykernel_10528/1825725989.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   all_data.groupby('City').sum()
#                      Quantity Ordered  Price Each   Month       Sales
# City
#  Atlanta (GA)                   16602  2779908.20  104794  2795498.58
#  Austin (TX)                    11153  1809873.61   69829  1819581.75
#  Boston (MA)                    22528  3637409.77  141112  3661642.01
#  Dallas (TX)                    16730  2752627.82  104620  2767975.40
#  Los Angeles (CA)               33289  5421435.23  208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741  4664317.43
#  Portland (ME)                   2750   447189.25   17144   449758.27
# ...

# %%
results = all_data.groupby('City').sum()
cities = [city for city, df in all_data.groupby('City')]
plt.bar(cities, results["Sales"])
plt.xticks(cities, rotation='vertical', size=8)
plt.ylabel('Sales in million USD($)')
plt.xlabel('City Name')
# Out:
# /var/folders/rj/nvyc7brx2p55bjzhqlxcrmpm0000gn/T/ipykernel_10528/2794413259.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results = all_data.groupby('City').sum()
# Text(0.5, 0, 'City Name')

# %% [markdown]
# ### What time should we diplay advertising to maximise likelihood of customers buying products?

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   209921        USB-C Charging Cable                 1       11.95
# 1   209922          Macbook Pro Laptop                 1     1700.00
# 2   209923             ThinkPad Laptop                 1      999.99
# 3   209924            27in FHD Monitor                 1      149.99
# 4   209925  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                       Purchase Address  Month    Sales  \
# 0 2019-06-23 19:34:00      950 Walnut St, Portland, ME 04101      6    11.95
# 1 2019-06-30 10:05:00     80 4th St, San Francisco, CA 94016      6  1700.00
# 2 2019-06-24 20:18:00  402 Jackson St, Los Angeles, CA 90001      6   999.99
# 3 2019-06-05 10:21:00         560 10th St, Seattle, WA 98101      6   149.99
# 4 2019-06-25 18:58:00    545 2nd St, San Francisco, CA 94016      6    99.99
#
#                   City
# 0        Portland (ME)
# 1   San Francisco (CA)
# ...

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data.tail()
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 186845   319666    Lightning Charging Cable                 1       14.95
# 186846   319667       AA Batteries (4-pack)                 2        3.84
# 186847   319668             Vareebadd Phone                 1      400.00
# 186848   319669            Wired Headphones                 1       11.99
# 186849   319670  Bose SoundSport Headphones                 1       99.99
#
#                 Order Date                        Purchase Address  Month  \
# 186845 2019-12-11 20:58:00  14 Madison St, San Francisco, CA 94016     12
# 186846 2019-12-01 12:01:00    549 Willow St, Los Angeles, CA 90001     12
# 186847 2019-12-09 06:43:00        273 Wilson St, Seattle, WA 98101     12
# 186848 2019-12-03 10:39:00          778 River St, Dallas, TX 75001     12
# 186849 2019-12-21 21:45:00  747 Chestnut St, Los Angeles, CA 90001     12
#
#          Sales                 City  Hour
# ...

# %%
all_data['Minute'] = all_data['Order Date'].dt.minute
all_data['Count'] = 1

# %%
hours = [hour for hour, df in all_data.groupby(['Hour'])];
plt.plot(hours, all_data.groupby(['Hour']).count()['Count'])
plt.grid()
plt.xticks(hours)
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
# Out:
# /var/folders/rj/nvyc7brx2p55bjzhqlxcrmpm0000gn/T/ipykernel_10528/3840410210.py:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   hours = [hour for hour, df in all_data.groupby(['Hour'])];
# Text(0, 0.5, 'Number of Orders')

# %% [markdown]
# Around 12pm or 7pm seems to be when most customers make purchases. So just before these times might be optimal to display ads.

# %% [markdown]
# ### Which products are most often sold together?

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df = df[['Order ID', 'Grouped']].drop_duplicates()
df
# Out:
# /var/folders/rj/nvyc7brx2p55bjzhqlxcrmpm0000gn/T/ipykernel_10528/729883513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#        Order ID                                          Grouped
# 17       209938                          iPhone,Wired Headphones
# 29       209949                Google Phone,USB-C Charging Cable
# 41       209960       USB-C Charging Cable,AA Batteries (4-pack)
# 43       209961                  iPhone,Lightning Charging Cable
# 147      210064        Lightning Charging Cable,27in FHD Monitor
# ...         ...                                              ...
# 186710   319536              Macbook Pro Laptop,Wired Headphones
# ...

# %%
from itertools import combinations
from collections import Counter

# %%
count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### What Product Sold the Most?

# %%
product_group = all_data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']
# Out:
# /var/folders/rj/nvyc7brx2p55bjzhqlxcrmpm0000gn/T/ipykernel_10528/1738041956.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   quantity_ordered = product_group.sum()['Quantity Ordered']
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# ...

# %%
products = [product for product,df in product_group]
plt.bar(products, quantity_ordered)
plt.xticks(products, rotation='vertical', size=8);
plt.ylabel('Quantity Ordered')
plt.xlabel('Product')
# Out:
# Text(0.5, 0, 'Product')
